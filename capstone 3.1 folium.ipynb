# %%
import folium
import pandas as pd

# %%
from folium.plugins import MarkerCluster
# Import folium MousePosition plugin
from folium.plugins import MousePosition
# Import folium DivIcon plugin
from folium.features import DivIcon

# %%
URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_geo.csv'
spacex_df=pd.read_csv(URL)

# %%
spacex_df
# Out:
#     Flight Number        Date Time (UTC) Booster Version   Launch Site  \
# 0               1  2010-06-04   18:45:00  F9 v1.0  B0003   CCAFS LC-40
# 1               2  2010-12-08   15:43:00  F9 v1.0  B0004   CCAFS LC-40
# 2               3  2012-05-22    7:44:00  F9 v1.0  B0005   CCAFS LC-40
# 3               4  2012-10-08    0:35:00  F9 v1.0  B0006   CCAFS LC-40
# 4               5  2013-03-01   15:10:00  F9 v1.0  B0007   CCAFS LC-40
# 5               7  2013-12-03   22:41:00         F9 v1.1   CCAFS LC-40
# 6               8  2014-01-06   22:06:00         F9 v1.1   CCAFS LC-40
# 7               9  2014-04-18   19:25:00         F9 v1.1   CCAFS LC-40
# 8              10  2014-07-14   15:15:00         F9 v1.1   CCAFS LC-40
# 9              11  2014-08-05    8:00:00         F9 v1.1   CCAFS LC-40
# 10             12  2014-09-07    5:00:00   F9 v1.1 B1011   CCAFS LC-40
# 11             13  2014-09-21    5:52:00   F9 v1.1 B1010   CCAFS LC-40
# 12             14  2015-01-10    9:47:00   F9 v1.1 B1012   CCAFS LC-40
# 13             15  2015-02-11   23:03:00   F9 v1.1 B1013   CCAFS LC-40
# 14             16  2015-03-02    3:50:00   F9 v1.1 B1014   CCAFS LC-40
# 15             17  2015-04-14   20:10:00   F9 v1.1 B1015   CCAFS LC-40
# 16             18  2015-04-27   23:03:00   F9 v1.1 B1016   CCAFS LC-40
# 17             19  2015-06-28   14:21:00   F9 v1.1 B1018   CCAFS LC-40
# 18             20  2015-12-22    1:29:00     F9 FT B1019   CCAFS LC-40
# 19             22  2016-03-04   23:35:00     F9 FT B1020   CCAFS LC-40
# 20             23  2016-04-08   20:43:00   F9 FT B1021.1   CCAFS LC-40
# 21             24  2016-05-06    5:21:00     F9 FT B1022   CCAFS LC-40
# 22             25  2016-05-27   21:39:00   F9 FT B1023.1   CCAFS LC-40
# 23             26  2016-06-15   14:29:00     F9 FT B1024   CCAFS LC-40
# 24             27  2016-07-18    4:45:00   F9 FT B1025.1   CCAFS LC-40
# 25             28  2016-08-14    5:26:00     F9 FT B1026   CCAFS LC-40
# 26              6  2013-09-29   16:00:00  F9 v1.1  B1003   VAFB SLC-4E
# 27             21  2016-01-17   18:42:00   F9 v1.1 B1017   VAFB SLC-4E
# 28             29  2017-01-14   17:54:00   F9 FT B1029.1   VAFB SLC-4E
# 29             37  2017-06-25   20:25:00   F9 FT B1036.1   VAFB SLC-4E
# 30             40  2017-08-24   18:51:00   F9 FT B1038.1   VAFB SLC-4E
# 31             42  2017-10-09   12:37:00   F9 B4 B1041.1   VAFB SLC-4E
# 32             46  2017-12-23    1:27:00  F9 FT  B1036.2   VAFB SLC-4E
# 33             49  2018-02-22   14:17:00  F9 FT  B1038.2   VAFB SLC-4E
# 34             51  2018-03-30   14:14:00  F9 B4  B1041.2   VAFB SLC-4E
# 35             55  2018-05-22   19:47:58  F9 B4  B1043.2   VAFB SLC-4E
# 36             30  2017-02-19   14:39:00   F9 FT B1031.1    KSC LC-39A
# 37             31  2017-03-16    6:00:00     F9 FT B1030    KSC LC-39A
# 38             32  2017-03-30   22:27:00  F9 FT  B1021.2    KSC LC-39A
# 39             33  2017-05-01   11:15:00   F9 FT B1032.1    KSC LC-39A
# 40             34  2017-05-15   23:21:00     F9 FT B1034    KSC LC-39A
# 41             35  2017-06-03   21:07:00   F9 FT B1035.1    KSC LC-39A
# 42             36  2017-06-23   19:10:00  F9 FT  B1029.2    KSC LC-39A
# 43             38  2017-07-05   23:38:00     F9 FT B1037    KSC LC-39A
# 44             39  2017-08-14   16:31:00   F9 B4 B1039.1    KSC LC-39A
# 45             41  2017-09-07   14:00:00   F9 B4 B1040.1    KSC LC-39A
# 46             43  2017-10-11   22:53:00  F9 FT  B1031.2    KSC LC-39A
# 47             44  2017-10-30   19:34:00   F9 B4 B1042.1    KSC LC-39A
# 48             54  2018-05-11   20:14:00  F9 B5  B1046.1    KSC LC-39A
# 49             45  2017-12-15   15:36:00  F9 FT  B1035.2  CCAFS SLC-40
# 50             47  2018-01-08    1:00:00   F9 B4 B1043.1  CCAFS SLC-40
# 51             48  2018-01-31   21:25:00  F9 FT  B1032.2  CCAFS SLC-40
# 52             50  2018-03-06    5:33:00     F9 B4 B1044  CCAFS SLC-40
# 53             52  2018-04-02   20:30:00  F9 B4  B1039.2  CCAFS SLC-40
# 54             53  2018-04-18   22:51:00   F9 B4 B1045.1  CCAFS SLC-40
# 55             56  2018-06-04    4:45:00  F9 B4  B1040.2  CCAFS SLC-40
#
#                                               Payload  Payload Mass (kg)  \
# 0                Dragon Spacecraft Qualification Unit               0.00
# 1   Dragon demo flight C1, two CubeSats,  barrel o...               0.00
# 2                              Dragon demo flight C2+             525.00
# 3                                        SpaceX CRS-1             500.00
# 4                                        SpaceX CRS-2             677.00
# 5                                               SES-8            3170.00
# 6                                           Thaicom 6            3325.00
# 7                                        SpaceX CRS-3            2296.00
# 8             OG2 Mission 1  6 Orbcomm-OG2 satellites            1316.00
# 9                                           AsiaSat 8            4535.00
# 10                                          AsiaSat 6            4428.00
# 11                                       SpaceX CRS-4            2216.00
# 12                                       SpaceX CRS-5            2395.00
# 13                                             DSCOVR             570.00
# 14                         ABS-3A Eutelsat 115 West B            4159.00
# 15                                       SpaceX CRS-6            1898.00
# 16                       TürkmenÄlem 52°E / MonacoSAT            4707.00
# 17                                       SpaceX CRS-7            1952.00
# 18          OG2 Mission 2   11 Orbcomm-OG2 satellites            2034.00
# 19                                              SES-9            5271.00
# 20                                       SpaceX CRS-8            3136.00
# 21                                           JCSAT-14            4696.00
# 22                                          Thaicom 8            3100.00
# 23                         ABS-2A Eutelsat 117 West B            3600.00
# 24                                       SpaceX CRS-9            2257.00
# 25                                           JCSAT-16            4600.00
# 26                                           CASSIOPE             500.00
# 27                                            Jason-3             553.00
# 28                                     Iridium NEXT 1            9600.00
# 29                                     Iridium NEXT 2            9600.00
# 30                                         Formosat-5             475.00
# 31                                     Iridium NEXT 3            9600.00
# 32                                     Iridium NEXT 4            9600.00
# 33                                  Paz  Tintin A & B            2150.00
# 34                                     Iridium NEXT 5            9600.00
# 35                     Iridium NEXT 6   GRACE-FO 1, 2            6460.00
# 36                                      SpaceX CRS-10            2490.00
# 37                                        EchoStar 23            5600.00
# 38                                             SES-10            5300.00
# 39                                            NROL-76            3696.65
# 40                                      Inmarsat-5 F4            6070.00
# 41                                      SpaceX CRS-11            2708.00
# 42                                      BulgariaSat-1            3669.00
# 43                                       Intelsat 35e            6761.00
# 44                                      SpaceX CRS-12            3310.00
# 45                                 Boeing X-37B OTV-5            4990.00
# 46                              SES-11 / EchoStar 105            5200.00
# 47                                        Koreasat 5A            3500.00
# 48                                      Bangabandhu-1            3600.00
# 49                                      SpaceX CRS-13            2205.00
# 50                                               Zuma            3696.65
# 51                                  GovSat-1 / SES-16            4230.00
# 52                             Hispasat 30W-6  PODSat            6092.00
# 53                                      SpaceX CRS-14            2647.00
# 54       Transiting Exoplanet Survey Satellite (TESS)             362.00
# 55                                             SES-12            5384.00
#
#            Orbit                            Customer          Landing Outcome  \
# 0            LEO                              SpaceX    Failure   (parachute)
# 1      LEO (ISS)                     NASA (COTS) NRO    Failure   (parachute)
# 2      LEO (ISS)                         NASA (COTS)               No attempt
# 3      LEO (ISS)                          NASA (CRS)               No attempt
# 4      LEO (ISS)                          NASA (CRS)               No attempt
# 5            GTO                                 SES               No attempt
# 6            GTO                             Thaicom               No attempt
# 7      LEO (ISS)                          NASA (CRS)       Controlled (ocean)
# 8            LEO                             Orbcomm       Controlled (ocean)
# 9            GTO                             AsiaSat               No attempt
# 10           GTO                             AsiaSat               No attempt
# 11     LEO (ISS)                          NASA (CRS)     Uncontrolled (ocean)
# 12     LEO (ISS)                          NASA (CRS)    Failure  (drone ship)
# 13  Sun–Earth L1            U.S. Air Force NASA NOAA       Controlled (ocean)
# 14           GTO                        ABS Eutelsat               No attempt
# 15     LEO (ISS)                          NASA (CRS)    Failure  (drone ship)
# 16           GTO  Turkmenistan National Space Agency               No attempt
# 17     LEO (ISS)                          NASA (CRS)  Precluded  (drone ship)
# 18           LEO                             Orbcomm    Success  (ground pad)
# 19           GTO                                 SES     Failure (drone ship)
# 20     LEO (ISS)                          NASA (CRS)    Success  (drone ship)
# 21           GTO              SKY Perfect JSAT Group     Success (drone ship)
# 22           GTO                             Thaicom    Success  (drone ship)
# 23           GTO                        ABS Eutelsat    Failure  (drone ship)
# 24     LEO (ISS)                          NASA (CRS)     Success (ground pad)
# 25           GTO              SKY Perfect JSAT Group     Success (drone ship)
# 26     Polar LEO                                 MDA     Uncontrolled (ocean)
# 27           LEO                NASA (LSP) NOAA CNES     Failure (drone ship)
# 28     Polar LEO              Iridium Communications    Success  (drone ship)
# 29           LEO              Iridium Communications     Success (drone ship)
# 30           SSO                                NSPO     Success (drone ship)
# 31     Polar LEO              Iridium Communications     Success (drone ship)
# 32     Polar LEO              Iridium Communications       Controlled (ocean)
# 33           SSO          Hisdesat exactEarth SpaceX               No attempt
# 34     Polar LEO              Iridium Communications               No attempt
# 35     Polar LEO   Iridium Communications GFZ • NASA               No attempt
# 36     LEO (ISS)                          NASA (CRS)     Success (ground pad)
# 37           GTO                            EchoStar               No attempt
# 38           GTO                                 SES     Success (drone ship)
# 39           LEO                                 NRO     Success (ground pad)
# 40           GTO                            Inmarsat               No attempt
# 41     LEO (ISS)                          NASA (CRS)     Success (ground pad)
# 42           GTO                           Bulsatcom     Success (drone ship)
# 43           GTO                            Intelsat               No attempt
# 44     LEO (ISS)                          NASA (CRS)     Success (ground pad)
# 45           LEO                      U.S. Air Force     Success (ground pad)
# 46           GTO                        SES EchoStar     Success (drone ship)
# 47           GTO                      KT Corporation     Success (drone ship)
# 48           GTO                  Thales-Alenia/BTRC     Success (drone ship)
# 49     LEO (ISS)                          NASA (CRS)     Success (ground pad)
# 50           LEO                    Northrop Grumman     Success (ground pad)
# 51           GTO                                 SES       Controlled (ocean)
# 52           GTO                 Hispasat  NovaWurks               No attempt
# 53     LEO (ISS)                          NASA (CRS)               No attempt
# 54           HEO                          NASA (LSP)     Success (drone ship)
# 55           GTO                                 SES               No attempt
#
#     class        Lat        Long
# 0       0  28.562302  -80.577356
# 1       0  28.562302  -80.577356
# 2       0  28.562302  -80.577356
# 3       0  28.562302  -80.577356
# 4       0  28.562302  -80.577356
# 5       0  28.562302  -80.577356
# 6       0  28.562302  -80.577356
# 7       0  28.562302  -80.577356
# 8       0  28.562302  -80.577356
# 9       0  28.562302  -80.577356
# 10      0  28.562302  -80.577356
# 11      0  28.562302  -80.577356
# 12      0  28.562302  -80.577356
# 13      0  28.562302  -80.577356
# 14      0  28.562302  -80.577356
# 15      0  28.562302  -80.577356
# 16      0  28.562302  -80.577356
# 17      1  28.562302  -80.577356
# 18      1  28.562302  -80.577356
# 19      0  28.562302  -80.577356
# 20      1  28.562302  -80.577356
# 21      1  28.562302  -80.577356
# 22      1  28.562302  -80.577356
# 23      0  28.562302  -80.577356
# 24      1  28.562302  -80.577356
# 25      1  28.562302  -80.577356
# 26      0  34.632834 -120.610745
# 27      0  34.632834 -120.610745
# 28      1  34.632834 -120.610745
# 29      1  34.632834 -120.610745
# 30      1  34.632834 -120.610745
# 31      1  34.632834 -120.610745
# 32      0  34.632834 -120.610745
# 33      0  34.632834 -120.610745
# 34      0  34.632834 -120.610745
# 35      0  34.632834 -120.610745
# 36      1  28.573255  -80.646895
# 37      0  28.573255  -80.646895
# 38      1  28.573255  -80.646895
# 39      1  28.573255  -80.646895
# 40      0  28.573255  -80.646895
# 41      1  28.573255  -80.646895
# 42      1  28.573255  -80.646895
# 43      0  28.573255  -80.646895
# 44      1  28.573255  -80.646895
# 45      1  28.573255  -80.646895
# 46      1  28.573255  -80.646895
# 47      1  28.573255  -80.646895
# 48      1  28.573255  -80.646895
# 49      1  28.563197  -80.576820
# 50      1  28.563197  -80.576820
# 51      0  28.563197  -80.576820
# 52      0  28.563197  -80.576820
# 53      0  28.563197  -80.576820
# 54      1  28.563197  -80.576820
# 55      0  28.563197  -80.576820

# %%
spacex_df = spacex_df[['Launch Site', 'Lat', 'Long', 'class']]

# %%
launch_sites_df = spacex_df.groupby(['Launch Site'], as_index=False).first()
launch_sites_df = launch_sites_df[['Launch Site', 'Lat', 'Long']]
launch_sites_df
# Out:
#     Launch Site        Lat        Long
# 0   CCAFS LC-40  28.562302  -80.577356
# 1  CCAFS SLC-40  28.563197  -80.576820
# 2    KSC LC-39A  28.573255  -80.646895
# 3   VAFB SLC-4E  34.632834 -120.610745

# %%
nasa_coordinate = [29.559684888503615, -95.0830971930759]
site_map = folium.Map(location=nasa_coordinate, zoom_start=10)

# %%
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e7255e3be153ed57f8677ea2bfcfd575 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e7255e3be153ed57f8677ea2bfcfd575&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e7255e3be153ed57f8677ea2bfcfd575 = L.map(
#                 &quot;map_e7255e3be153ed57f8677ea2bfcfd575&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a4421c6898a63f0ea20a4c256bf729a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6a4421c6898a63f0ea20a4c256bf729a.addTo(map_e7255e3be153ed57f8677ea2bfcfd575);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
circle = folium.Circle(nasa_coordinate, radius=1000, color='#d35400', fill=True).add_child(folium.Popup('NASA Johnson Space Center'))
# Create a blue circle at NASA Johnson Space Center's coordinate with a icon showing its name
marker = folium.map.Marker(
    nasa_coordinate,
    # Create an icon as a text label
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % 'NASA JSC',
        )
    )
site_map.add_child(circle)
site_map.add_child(marker)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d9335e9341176cd49f79d391d8d376d4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d9335e9341176cd49f79d391d8d376d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d9335e9341176cd49f79d391d8d376d4 = L.map(
#                 &quot;map_d9335e9341176cd49f79d391d8d376d4&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fc22ccd646729b1a6f79b9dfc6cdfade = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fc22ccd646729b1a6f79b9dfc6cdfade.addTo(map_d9335e9341176cd49f79d391d8d376d4);
#
#
#             tile_layer_fc22ccd646729b1a6f79b9dfc6cdfade.addTo(map_d9335e9341176cd49f79d391d8d376d4);
#
#
#             var circle_89d425e960c71d3bf2bf063bf9de917d = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d9335e9341176cd49f79d391d8d376d4);
#
#
#         var popup_61043e705abd7e6366f876f483813cb3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_06ed2d1c3c2611077e4a4194899ddd47 = $(`&lt;div id=&quot;html_06ed2d1c3c2611077e4a4194899ddd47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_61043e705abd7e6366f876f483813cb3.setContent(html_06ed2d1c3c2611077e4a4194899ddd47);
#
#
#
#         circle_89d425e960c71d3bf2bf063bf9de917d.bindPopup(popup_61043e705abd7e6366f876f483813cb3)
#         ;
#
#
#
#
#             tile_layer_fc22ccd646729b1a6f79b9dfc6cdfade.addTo(map_d9335e9341176cd49f79d391d8d376d4);
#
#
#             var circle_b331a0584f818911f9af8c0badc65eb6 = L.circle(
#                 [29.559684888503615, -95.0830971930759],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d9335e9341176cd49f79d391d8d376d4);
#
#
#         var popup_69d67d0dd33bacd7f7679a2a3b26ce34 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6a3919e5bda0af2776d8fd1ca8685f94 = $(`&lt;div id=&quot;html_6a3919e5bda0af2776d8fd1ca8685f94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NASA Johnson Space Center&lt;/div&gt;`)[0];
#                 popup_69d67d0dd33bacd7f7679a2a3b26ce34.setContent(html_6a3919e5bda0af2776d8fd1ca8685f94);
#
#
#
#         circle_b331a0584f818911f9af8c0badc65eb6.bindPopup(popup_69d67d0dd33bacd7f7679a2a3b26ce34)
#         ;
#
#
#
#
#             var marker_03b2f47f9d3725dd0f0f3ff540d02f30 = L.marker(
#                 [29.559684888503615, -95.0830971930759],
#                 {}
#             ).addTo(map_d9335e9341176cd49f79d391d8d376d4);
#
#
#             var div_icon_0e607668012b16f2211c4eca41c56433 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eNASA JSC\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_03b2f47f9d3725dd0f0f3ff540d02f30.setIcon(div_icon_0e607668012b16f2211c4eca41c56433);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
site_map = folium.Map(location=nasa_coordinate, zoom_start=5)

for lat , lng , launch in zip(spacex_df["Lat"],spacex_df["Long"],spacex_df["Launch Site"]) :
    circle = folium.Circle([lat,lng], radius=1000, color='#d35400', fill=True).add_child(folium.Popup(launch))
    marker = folium.Marker([lat,lng],
                          icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % launch,))
     
    site_map.add_child(circle)
    site_map.add_child(marker)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e019aa6cffe415862c58433bfb3c7404 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e019aa6cffe415862c58433bfb3c7404&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e019aa6cffe415862c58433bfb3c7404 = L.map(
#                 &quot;map_e019aa6cffe415862c58433bfb3c7404&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6c09e2dd5e3bdb8d117a15af5a9d76ba = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6c09e2dd5e3bdb8d117a15af5a9d76ba.addTo(map_e019aa6cffe415862c58433bfb3c7404);
#
#
#             var circle_36d783d806d45f1819e7f3b49432a696 = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e019aa6cffe415862c58433bfb3c7404);
#
#
#         var popup_92ca7f10cf9148a8b1533f0b0492f9b6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cfe1d5677dfb7fb5e46d8c0a3de27d69 = $(`&lt;div id=&quot;html_cfe1d5677dfb7fb5e46d8c0a3de27d69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_92ca7f10cf9148a8b1533f0b0492f9b6.setContent(html_cfe1d5677dfb7fb5e46d8c0a3de27d69);
#
#
#
#         circle_36d783d806d45f1819e7f3b49432a696.bindPopup(popup_92ca7f10cf9148a8b1533f0b0492f9b6)
#         ;
#
#
#
#
#             var marker_3c394ec2315e4205dfc2330144f6faa2 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(map_e019aa6cffe415862c58433bfb3c7404);
#
#
#             var div_icon_334f25c4690a214d2cabc693ffa7b731 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eCCAFS LC-40\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_3c394ec2315e4205dfc2330144f6faa2.setIcon(div_icon_334f25c4690a214d2cabc693ffa7b731);
#
#
#             var circle_08adfcaf67197d0f0f7539043e909448 = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#d35400&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e019aa6cffe415862c58433bfb3c7404);
#
#
#         var popup_634a767118695c187a41a37474771640 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3dbd8834074f836ac149d3cc15230e46 = $(`&lt;div id=&quot;html_3dbd8834074f836ac149d3cc15230e46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;CCAFS LC-40&lt;/div&gt;`)[0];
#                 popup_634a767118695c187a41a37474771640.setContent(html_3dbd8834074f836ac149d3cc15230e46);
#
#
#
#         circle_08adfcaf67197d0f0f7539043e909448.bindPopup(popup_634a767118695c187a41a37474771640)
#         ;
#
#
#
#
#             var marker_be69fffc90ba6a4a78f543271df0d42c = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(map_e019aa6cffe415862c58433bfb3c7404);
#
#
#             var div_icon_904a0f38e16926c688b20b90cffbe35b = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12; color:#d35400;\&quot;\u003e\u003cb\u003eCCAFS LC-40\u003c/b\u003e\u003c/div\u003e&quot;, &quot;iconAnchor&quot;: [0, 0], &quot;iconSize&quot;: [20, 20]});
#             marker_be69fffc90ba6a4a78f543271df0d42c.setIcon(div_icon_904a0f38e16926c688b20b90cffbe35b);
#
#
#             var circle_db0fe2f14d0df4e3223ac858eff60254 = L.circle(
#                 [28.56230197, -80.57735648],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#d35400&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#

# %%
marker_cluster = MarkerCluster()

# %%
for i,Class in enumerate(spacex_df["class"]) :
    if Class == 0 :
        spacex_df.loc[i,"Color"] = "red"
    else :
        spacex_df.loc[i,"Color"] = "green"

# %%
spacex_df
# Out:
#      Launch Site        Lat        Long  class  Color
# 0    CCAFS LC-40  28.562302  -80.577356      0    red
# 1    CCAFS LC-40  28.562302  -80.577356      0    red
# 2    CCAFS LC-40  28.562302  -80.577356      0    red
# 3    CCAFS LC-40  28.562302  -80.577356      0    red
# 4    CCAFS LC-40  28.562302  -80.577356      0    red
# 5    CCAFS LC-40  28.562302  -80.577356      0    red
# 6    CCAFS LC-40  28.562302  -80.577356      0    red
# 7    CCAFS LC-40  28.562302  -80.577356      0    red
# 8    CCAFS LC-40  28.562302  -80.577356      0    red
# 9    CCAFS LC-40  28.562302  -80.577356      0    red
# 10   CCAFS LC-40  28.562302  -80.577356      0    red
# 11   CCAFS LC-40  28.562302  -80.577356      0    red
# 12   CCAFS LC-40  28.562302  -80.577356      0    red
# 13   CCAFS LC-40  28.562302  -80.577356      0    red
# 14   CCAFS LC-40  28.562302  -80.577356      0    red
# 15   CCAFS LC-40  28.562302  -80.577356      0    red
# 16   CCAFS LC-40  28.562302  -80.577356      0    red
# 17   CCAFS LC-40  28.562302  -80.577356      1  green
# 18   CCAFS LC-40  28.562302  -80.577356      1  green
# 19   CCAFS LC-40  28.562302  -80.577356      0    red
# 20   CCAFS LC-40  28.562302  -80.577356      1  green
# 21   CCAFS LC-40  28.562302  -80.577356      1  green
# 22   CCAFS LC-40  28.562302  -80.577356      1  green
# 23   CCAFS LC-40  28.562302  -80.577356      0    red
# 24   CCAFS LC-40  28.562302  -80.577356      1  green
# 25   CCAFS LC-40  28.562302  -80.577356      1  green
# 26   VAFB SLC-4E  34.632834 -120.610745      0    red
# 27   VAFB SLC-4E  34.632834 -120.610745      0    red
# 28   VAFB SLC-4E  34.632834 -120.610745      1  green
# 29   VAFB SLC-4E  34.632834 -120.610745      1  green
# 30   VAFB SLC-4E  34.632834 -120.610745      1  green
# 31   VAFB SLC-4E  34.632834 -120.610745      1  green
# 32   VAFB SLC-4E  34.632834 -120.610745      0    red
# 33   VAFB SLC-4E  34.632834 -120.610745      0    red
# 34   VAFB SLC-4E  34.632834 -120.610745      0    red
# 35   VAFB SLC-4E  34.632834 -120.610745      0    red
# 36    KSC LC-39A  28.573255  -80.646895      1  green
# 37    KSC LC-39A  28.573255  -80.646895      0    red
# 38    KSC LC-39A  28.573255  -80.646895      1  green
# 39    KSC LC-39A  28.573255  -80.646895      1  green
# 40    KSC LC-39A  28.573255  -80.646895      0    red
# 41    KSC LC-39A  28.573255  -80.646895      1  green
# 42    KSC LC-39A  28.573255  -80.646895      1  green
# 43    KSC LC-39A  28.573255  -80.646895      0    red
# 44    KSC LC-39A  28.573255  -80.646895      1  green
# 45    KSC LC-39A  28.573255  -80.646895      1  green
# 46    KSC LC-39A  28.573255  -80.646895      1  green
# 47    KSC LC-39A  28.573255  -80.646895      1  green
# 48    KSC LC-39A  28.573255  -80.646895      1  green
# 49  CCAFS SLC-40  28.563197  -80.576820      1  green
# 50  CCAFS SLC-40  28.563197  -80.576820      1  green
# 51  CCAFS SLC-40  28.563197  -80.576820      0    red
# 52  CCAFS SLC-40  28.563197  -80.576820      0    red
# 53  CCAFS SLC-40  28.563197  -80.576820      0    red
# 54  CCAFS SLC-40  28.563197  -80.576820      1  green
# 55  CCAFS SLC-40  28.563197  -80.576820      0    red

# %%
site_map.add_child(marker_cluster)
for index,record in spacex_df.iterrows():
    marker=folium.Marker([record["Lat"],record["Long"]],
                        icon = folium.Icon(color='white', icon_color=record['Color'] ,
                        html='<div style="font-size: 20pt">%s</div>' %record["Launch Site"]))
    marker_cluster.add_child(marker)

# %%
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e7255e3be153ed57f8677ea2bfcfd575 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e7255e3be153ed57f8677ea2bfcfd575&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e7255e3be153ed57f8677ea2bfcfd575 = L.map(
#                 &quot;map_e7255e3be153ed57f8677ea2bfcfd575&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a4421c6898a63f0ea20a4c256bf729a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6a4421c6898a63f0ea20a4c256bf729a.addTo(map_e7255e3be153ed57f8677ea2bfcfd575);
#
#
#             tile_layer_6a4421c6898a63f0ea20a4c256bf729a.addTo(map_e7255e3be153ed57f8677ea2bfcfd575);
#
#
#             var marker_cluster_64b072d537113634df528c4b3a22b9d9 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_64b072d537113634df528c4b3a22b9d9.addTo(map_e7255e3be153ed57f8677ea2bfcfd575);
#
#
#             tile_layer_6a4421c6898a63f0ea20a4c256bf729a.addTo(map_e7255e3be153ed57f8677ea2bfcfd575);
#
#
#             marker_cluster_64b072d537113634df528c4b3a22b9d9.addTo(map_e7255e3be153ed57f8677ea2bfcfd575);
#
#
#             var marker_d9243e4daa4b5b023fe9dc93c0bc2e6e = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(marker_cluster_64b072d537113634df528c4b3a22b9d9);
#
#
#             var icon_755ba2f92e008bad2fc7c15936a2b6c1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d9243e4daa4b5b023fe9dc93c0bc2e6e.setIcon(icon_755ba2f92e008bad2fc7c15936a2b6c1);
#
#
#             var marker_52d4b44c583055912f0ce9eead592e37 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(marker_cluster_64b072d537113634df528c4b3a22b9d9);
#
#
#             var icon_9dbd0b4d71c7fba2b4790d52ccd3aa6b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_52d4b44c583055912f0ce9eead592e37.setIcon(icon_9dbd0b4d71c7fba2b4790d52ccd3aa6b);
#
#
#             var marker_8d7ee347da117a1eb44701d0905dbbd6 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(marker_cluster_64b072d537113634df528c4b3a22b9d9);
#
#
#             var icon_ad437ec0927f54c35e192941de4c6f66 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8d7ee347da117a1eb44701d0905dbbd6.setIcon(icon_ad437ec0927f54c35e192941de4c6f66);
#
#
#             var marker_ab25fa1fe3cb214444ea45579eb0667e = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(marker_cluster_64b072d537113634df528c4b3a22b9d9);
#
#
#             var icon_adff3ffdcb4aa59d83e6398f71bc72b1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ab25fa1fe3cb214444ea45579eb0667e.setIcon(icon_adff3ffdcb4aa59d83e6398f71bc72b1);
#
#
#             var marker_c7fe67307b537e7cf5708ece0ed6d1a0 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(marker_cluster_64b072d537113634df528c4b3a22b9d9);
#
#
#             var icon_040c8f21f2a72c2cd3f670ed7a6954ac = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;red&quot;, &qu

# %%
formatter = "function(num) {return L.Util.formatNum(num, 5);};"
mouse_position = MousePosition(
    position='topright',
    separator=' Long: ',
    empty_string='NaN',
    lng_first=False,
    num_digits=20,
    prefix='Lat:',
    lat_formatter=formatter,
    lng_formatter=formatter,
)

site_map.add_child(mouse_position)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e7255e3be153ed57f8677ea2bfcfd575 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e7255e3be153ed57f8677ea2bfcfd575&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e7255e3be153ed57f8677ea2bfcfd575 = L.map(
#                 &quot;map_e7255e3be153ed57f8677ea2bfcfd575&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a4421c6898a63f0ea20a4c256bf729a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6a4421c6898a63f0ea20a4c256bf729a.addTo(map_e7255e3be153ed57f8677ea2bfcfd575);
#
#
#             tile_layer_6a4421c6898a63f0ea20a4c256bf729a.addTo(map_e7255e3be153ed57f8677ea2bfcfd575);
#
#
#             var marker_cluster_64b072d537113634df528c4b3a22b9d9 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_64b072d537113634df528c4b3a22b9d9.addTo(map_e7255e3be153ed57f8677ea2bfcfd575);
#
#
#             tile_layer_6a4421c6898a63f0ea20a4c256bf729a.addTo(map_e7255e3be153ed57f8677ea2bfcfd575);
#
#
#             marker_cluster_64b072d537113634df528c4b3a22b9d9.addTo(map_e7255e3be153ed57f8677ea2bfcfd575);
#
#
#             var marker_d9243e4daa4b5b023fe9dc93c0bc2e6e = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(marker_cluster_64b072d537113634df528c4b3a22b9d9);
#
#
#             var icon_755ba2f92e008bad2fc7c15936a2b6c1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d9243e4daa4b5b023fe9dc93c0bc2e6e.setIcon(icon_755ba2f92e008bad2fc7c15936a2b6c1);
#
#
#             var marker_52d4b44c583055912f0ce9eead592e37 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(marker_cluster_64b072d537113634df528c4b3a22b9d9);
#
#
#             var icon_9dbd0b4d71c7fba2b4790d52ccd3aa6b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_52d4b44c583055912f0ce9eead592e37.setIcon(icon_9dbd0b4d71c7fba2b4790d52ccd3aa6b);
#
#
#             var marker_8d7ee347da117a1eb44701d0905dbbd6 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(marker_cluster_64b072d537113634df528c4b3a22b9d9);
#
#
#             var icon_ad437ec0927f54c35e192941de4c6f66 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8d7ee347da117a1eb44701d0905dbbd6.setIcon(icon_ad437ec0927f54c35e192941de4c6f66);
#
#
#             var marker_ab25fa1fe3cb214444ea45579eb0667e = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(marker_cluster_64b072d537113634df528c4b3a22b9d9);
#
#
#             var icon_adff3ffdcb4aa59d83e6398f71bc72b1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ab25fa1fe3cb214444ea45579eb0667e.setIcon(icon_adff3ffdcb4aa59d83e6398f71bc72b1);
#
#
#             var marker_c7fe67307b537e7cf5708ece0ed6d1a0 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(

# %%
from math import sin, cos, sqrt, atan2, radians

def calculate_distance(lat1, lon1, lat2, lon2):
    # approximate radius of earth in km
    R = 6373.0

    lat1 = radians(lat1)
    lon1 = radians(lon1)
    lat2 = radians(lat2)
    lon2 = radians(lon2)

    dlon = lon2 - lon1
    dlat = lat2 - lat1

    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))

    distance = R * c
    return distance

# %%
coordinates = [
    [28.56342, -80.57674],
    [28.56342, -80.56756]]
distance = calculate_distance(coordinates[0][0], coordinates[0][1], coordinates[1][0], coordinates[1][1])
distance
# Out:
# 0.8968114005914352

# %%
coordinates = [
    [28.56342, -80.57674],
    [28.56342, -80.56756]]

lines=folium.PolyLine(locations=coordinates, weight=1)
site_map.add_child(lines)
distance = calculate_distance(coordinates[0][0], coordinates[0][1], coordinates[1][0], coordinates[1][1])
distance_circle = folium.Marker( 
    [28.56342, -80.56794],
    icon=DivIcon(
        icon_size=(20,20),
        icon_anchor=(0,0),
        html='<div style="font-size: 12; color:#d35400;"><b>%s</b></div>' % "{:10.2f} KM".format(distance),
        )
    )
site_map.add_child(distance_circle)
site_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e7255e3be153ed57f8677ea2bfcfd575 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ardhi/Leaflet.MousePosition/src/L.Control.MousePosition.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e7255e3be153ed57f8677ea2bfcfd575&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e7255e3be153ed57f8677ea2bfcfd575 = L.map(
#                 &quot;map_e7255e3be153ed57f8677ea2bfcfd575&quot;,
#                 {
#                     center: [29.559684888503615, -95.0830971930759],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a4421c6898a63f0ea20a4c256bf729a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6a4421c6898a63f0ea20a4c256bf729a.addTo(map_e7255e3be153ed57f8677ea2bfcfd575);
#
#
#             tile_layer_6a4421c6898a63f0ea20a4c256bf729a.addTo(map_e7255e3be153ed57f8677ea2bfcfd575);
#
#
#             var marker_cluster_64b072d537113634df528c4b3a22b9d9 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_64b072d537113634df528c4b3a22b9d9.addTo(map_e7255e3be153ed57f8677ea2bfcfd575);
#
#
#             tile_layer_6a4421c6898a63f0ea20a4c256bf729a.addTo(map_e7255e3be153ed57f8677ea2bfcfd575);
#
#
#             marker_cluster_64b072d537113634df528c4b3a22b9d9.addTo(map_e7255e3be153ed57f8677ea2bfcfd575);
#
#
#             var marker_d9243e4daa4b5b023fe9dc93c0bc2e6e = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(marker_cluster_64b072d537113634df528c4b3a22b9d9);
#
#
#             var icon_755ba2f92e008bad2fc7c15936a2b6c1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d9243e4daa4b5b023fe9dc93c0bc2e6e.setIcon(icon_755ba2f92e008bad2fc7c15936a2b6c1);
#
#
#             var marker_52d4b44c583055912f0ce9eead592e37 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(marker_cluster_64b072d537113634df528c4b3a22b9d9);
#
#
#             var icon_9dbd0b4d71c7fba2b4790d52ccd3aa6b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_52d4b44c583055912f0ce9eead592e37.setIcon(icon_9dbd0b4d71c7fba2b4790d52ccd3aa6b);
#
#
#             var marker_8d7ee347da117a1eb44701d0905dbbd6 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(marker_cluster_64b072d537113634df528c4b3a22b9d9);
#
#
#             var icon_ad437ec0927f54c35e192941de4c6f66 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8d7ee347da117a1eb44701d0905dbbd6.setIcon(icon_ad437ec0927f54c35e192941de4c6f66);
#
#
#             var marker_ab25fa1fe3cb214444ea45579eb0667e = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(marker_cluster_64b072d537113634df528c4b3a22b9d9);
#
#
#             var icon_adff3ffdcb4aa59d83e6398f71bc72b1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;red&quot;, &quot;markerColor&quot;: &quot;white&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ab25fa1fe3cb214444ea45579eb0667e.setIcon(icon_adff3ffdcb4aa59d83e6398f71bc72b1);
#
#
#             var marker_c7fe67307b537e7cf5708ece0ed6d1a0 = L.marker(
#                 [28.56230197, -80.57735648],
#                 {}
#             ).addTo(
